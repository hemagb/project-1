# %%
# Import dependencies
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from api_key import api_key
from pprint import pprint

# %%
# Print api to take a look at structure 

# Population
'https://api.datausa.io/api?show=geo&sumlevel=nation&required=pop'
# Out:
# {'DisasterDeclarationsSummaries': [{'declarationDate': '1953-05-02T00:00:00.000Z',
#                                     'declaredCountyArea': '',
#                                     'disasterCloseOutDate': '1954-06-01T00:00:00.000Z',
#                                     'disasterNumber': 1,
#                                     'disasterType': 'DR',
#                                     'fyDeclared': 1953,
#                                     'hash': 'e6f77c3a97c63d478bf14c9a58f60a0d',
#                                     'hmProgramDeclared': True,
#                                     'iaProgramDeclared': True,
#                                     'id': '5a2e8810758c6e4347e5ece1',
#                                     'ihProgramDeclared': False,
#                                     'incidentBeginDate': '1953-05-02T00:00:00.000Z',
#                                     'incidentEndDate': '1953-05-02T00:00:00.000Z',
# ...
